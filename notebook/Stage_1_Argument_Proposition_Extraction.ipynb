# %% [markdown]
# # Import

# %%
import pandas as pd
import ast
import numpy as np
import re

# %%
import spacy
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# # Read Data

# %%
dfs = []
for subset in ['reddit', 'nyt', 'stack']:
    temp_df = pd.read_csv(f"../data/{subset}/raw_input.csv")
    dfs += [temp_df]
    
df = pd.concat(dfs)

# %% [markdown]
# # Argument Proposition Extraction

# %%
df = df.explode(['comments'])

# %%
import os
from openai import OpenAI
client = OpenAI(
    api_key = "<your-api-key-here"
)

# %%
# model="gpt-4.1-mini"
# model="gpt-4o-mini"
model="gpt-4.1"
# model="gpt-4"
# model="gpt-3.5-turbo"

prompt = "Once upon a time"

# %%
def get_completion(prompt, model=model):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=1500,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
# BEST
INFERENCE_PROMPT = """Help me extract the proposition of the given comment according to Toulmin model. Extracted proposition should be original sentences/phrases from the comment. You can ignore non argumentative unit/senteces. Every proposition must refer to a specific object/subject the subject and cannot be pronoun (e.g., it, this, that):

Extract all possible claims and their propositions as a list of JSONs:
[{'claim': <claim>, 'ground': [<list of grounds>], ...}, ...]

For example:
Comment: You should girafarig because it's the best pokemon ever created no matter what ANYONE SAYS.
Proposition: [{"claim": "You should girafarig", "ground": ["girafarig is the best pokemon ever created no matter what ANYONE SAYS"]}]

Now perform on the following output:
"%s"
"""

# %%
row = df.iloc[14]
row['comments']
# Out:
# '[\'Looks pretty cool. Would have been nice to not have that background music though, its kind of distracting\', "The background music is a demo track made entirely using the synth. It\'s still distracting and it\'s poorly communicated but it\'s not like they\'re playing something completely unrelated over the demo video.", \'would be interested in it if its available for a decent price. would look very nice in my studio\', "Looks sick. Wish I didn\'t have to email info for a price, but the synth itself looks awesome. I\'ve been looking for something like this.", \'Why not just use famitracker or LSDJ??\', \'cuz having a physical interface is infinitely more intuitive and conducive to creativity?\', \'Because LSDJ and actual gameboy with little modification is a lot more convenient.\', \'maybe you underestimate what using a 4-directional gamepad feels like to people without autism\', \'Looks fun as hell.\', \'Looks pretty noice :)\', \'Well this thing shits on my Meeblip.\', \'This has come out now I noticed: http://soulsbysynths.blogspot.jp/2014/03/soulsby-synthesizers-atmegatron-goes-on.html?spref=fb\', \'So....it runs on arduino software....is that just an arduino board hooked up to a nice looking backplate that will only do things that my computer can already do with free VSTs? Sure looks like it. Anyone that buys this is stupid.\', \'Well in that case anyone who buys hardware is stupid.\', "Analog shit is great. You can hear the electricity flowing through the circuits and it has that extra ~thing~ in it that makes it special. Digital....not so much. If you can download a free/cheap vst that will do the same thing as the hardware, then yes, you\'re dumb. This is one of those cases.", "Except working with hardware allows for a different workflow that many prefer and it\'s more suitable for playing live.", \'agreed, which is why they would have to come up with a reasonable price. if they have a good price then this is a perfect little piece of gear. hardware synths are a lot more fun to work with than equal software counterparts.\', "It uses an Atmega processor, but definitely isn\'t an Arduino gaffered into a metal box!!!  It\'s a custom manufactured PCB.     See my blog for an answer to the VST question: http://soulsbysynths.blogspot.co.uk/", \'Love the classic looking design but i hate 8bit.... I would love a nice small like this but for more modern sounds!\', \'Look for a Shruthi-1 synth by Mutable Instruments.\', \'Thanks!!!\']'

# %%
prompt = INFERENCE_PROMPT % (row['comments'])

# %%
response = get_completion(prompt, model)

# %%
print(response)
# Out:
# ```json
# [
#   {
#     "claim": "The background music is a demo track made entirely using the synth",
#     "ground": []
#   },
#   {
#     "claim": "The background music is distracting",
#     "ground": []
#   },
#   {
#     "claim": "The background music is poorly communicated",
#     "ground": []
#   },
#   {
#     "claim": "The synth would look very nice in my studio",
#     "ground": []
#   },
#   {
#     "claim": "I would be interested in the synth if it is available for a decent price",
#     "ground": []
#   },
#   {
#     "claim": "The synth looks awesome",
#     "ground": []
#   },
#   {
#     "claim": "I have been looking for something like this synth",
#     "ground": []
#   },
#   {
#     "claim": "Having a physical interface is infinitely more intuitive and conducive to creativity",
#     "ground": []
#   },
#   {
#     "claim": "LSDJ and actual Gameboy with little modification is a lot more convenient",
#     "ground": []
#   },
#   {
#     "claim": "Using a 4-directional gamepad feels different to people without autism",
#     "ground": []
#   },
#   {
#     "claim": "This synth shits on my Meeblip",
#     "ground": []
#   },
#   {
#     "claim": "The synth runs on Arduino software",
#     "ground": []
#   },
#   {
#     "claim": "The synth is just an Arduino board hooked up to a nice looking backplate that will only do things that my computer can already do with free VSTs",
#     "ground": []
#   },
#   {
#     "claim": "Anyone that buys this synth is stupid",
#     "ground": [
#       "The synth is just an Arduino board hooked up to a nice looking backplate that will only do things that my computer can already do with free VSTs"
#     ]
#   },
#   {
#     "claim": "Anyone who buys hardware is stupid",
#     "ground": []
#   },
#   {
#     "claim": "Analog synths are great",
#     "ground": [
#       "You can hear the electricity flowing through the circuits",
#       "Analog synths have that extra ~thing~ in it that makes it special"
#     ]
#   },
#   {
#     "claim": "Digital synths are not as great as analog synths",
#     "ground": []
#   },
#   {
#     "claim": "If you can download a free/cheap VST that will do the same thing as the hardware, then you are dumb",
#     "ground": []
#   },
#   {
#     "claim": "This synth is one of those cases where a free/cheap VST can do the same thing as the hardware",
#     "ground": []
#   },
#   {
#     "claim": "Working with hardware allows for a different workflow that many prefer",
#     "ground": []
#   },
#   {
#     "claim": "Hardware is more suitable for playing live",
#     "ground": []
#   },
#   {
#     "claim": "They would have to come up with a reasonable price for the synth",
#     "ground": []
#   },
#   {
#     "claim": "If they have a good price then this is a perfect little piece of gear",
#     "ground": []
#   },
#   {
#     "claim": "Hardware synths are a lot more fun to work with than equal software counterparts",
#     "ground": []
#   },
#   {
#     "claim": "The synth uses an Atmega processor",
#     "ground": []
#   },
#   {
#     "claim": "The synth definitely isn't an Arduino gaffered into a metal box",
#     "ground": [
#       "It's a custom manufactured PCB"
#     ]
#   },
#   {
#     "claim": "I love the classic looking design of the synth",
#     "ground": []
#   },
#   {
#     "claim": "I hate 8bit",
#     "ground": []
#   },
#   {
#     "claim": "I would love a nice small synth like this but for more modern sounds",
#     "ground": []
#   }
# ]
# ```

# %% [markdown]
# ## Inference

# %%
def get_proposition_completion(comments):
    prompt = INFERENCE_PROMPT % (comments)
    try:
        return get_completion(prompt, model)
    except:
        return None

# %%
results = []
for i, row in df.iterrows():
    comments = row['comments']
    if pd.isnull(comments) or len(comments.strip()) == 0:
        arg_propositions += [np.nan]
    else:
        arg_proposition = get_proposition_completion(comments)
        results += [arg_proposition]
        time.sleep(0.1)

# %%
df['arg_propositions'] = results

# %%
for subset in ['reddit', 'nyt', 'stack']:
    temp_df = df[df['subset'] == subset]
    temp_df.to_csv(f"../data/{subset}/source_comments_arg_extracted.csv", index=False)
